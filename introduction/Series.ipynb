# %%
import pandas as pd

# %% [markdown]
# # Import series With read_csv method

# %%
pokemon = pd.read_csv("pokemon.csv", usecols=["type1"], squeeze=True)
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
pokemon
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
foods = pd.read_csv("foods.csv", usecols=["Menu Item"], squeeze=True)
foods
# Out:
# 0            Big Mac
# 1          McNuggets
# 2    Quarter Pounder
# Name: Menu Item, dtype: object

# %% [markdown]
# # The .head() and .tail() Method

# %%
foods = pd.read_csv("foods.csv", usecols=["Menu Item"], squeeze=True)

# %%
foods.head()
# Out:
# 0            Big Mac
# 1          McNuggets
# 2    Quarter Pounder
# Name: Menu Item, dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv", usecols=["type1"], squeeze=True)

# %%
pokemon.head(6)
# Out:
# 0    grass
# 1    grass
# 2    grass
# 3     fire
# 4     fire
# 5     fire
# Name: type1, dtype: object

# %%
pokemon.tail(2)
# Out:
# 799    psychic
# 800      steel
# Name: type1, dtype: object

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
sorted(pokemon)
# Out:
# ['bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
#  'dark',
# ...

# %%
len(pokemon)
# Out:
# 801

# %%
pokemon.shape
# Out:
# (801,)

# %%
list(pokemon)
# Out:
# ['grass',
#  'grass',
#  'grass',
#  'fire',
#  'fire',
#  'fire',
#  'water',
#  'water',
#  'water',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'poison',
#  'poison',
#  'electric',
#  'electric',
#  'ground',
#  'ground',
#  'poison',
#  'poison',
#  'poison',
#  'poison',
#  'poison',
#  'poison',
#  'fairy',
#  'fairy',
#  'fire',
#  'fire',
#  'normal',
#  'normal',
#  'poison',
#  'poison',
#  'grass',
#  'grass',
#  'grass',
#  'bug',
#  'bug',
#  'bug',
#  'bug',
#  'ground',
#  'ground',
#  'normal',
#  'normal',
#  'water',
#  'water',
#  'fighting',
#  'fighting',
#  'fire',
#  'fire',
#  'water',
#  'water',
#  'water',
#  'psychic',
#  'psychic',
#  'psychic',
#  'fighting',
#  'fighting',
#  'fighting',
#  'grass',
#  'grass',
#  'grass',
#  'water',
#  'water',
#  'rock',
#  'rock',
#  'rock',
#  'fire',
#  'fire',
#  'water',
#  'water',
#  'electric',
# ...

# %%
dict(pokemon)
# Out:
# {0: 'grass',
#  1: 'grass',
#  2: 'grass',
#  3: 'fire',
#  4: 'fire',
#  5: 'fire',
#  6: 'water',
#  7: 'water',
#  8: 'water',
#  9: 'bug',
#  10: 'bug',
#  11: 'bug',
#  12: 'bug',
#  13: 'bug',
#  14: 'bug',
#  15: 'normal',
#  16: 'normal',
#  17: 'normal',
#  18: 'normal',
#  19: 'normal',
#  20: 'normal',
#  21: 'normal',
#  22: 'poison',
#  23: 'poison',
#  24: 'electric',
#  25: 'electric',
#  26: 'ground',
#  27: 'ground',
#  28: 'poison',
#  29: 'poison',
#  30: 'poison',
#  31: 'poison',
#  32: 'poison',
#  33: 'poison',
#  34: 'fairy',
#  35: 'fairy',
#  36: 'fire',
#  37: 'fire',
#  38: 'normal',
#  39: 'normal',
#  40: 'poison',
#  41: 'poison',
#  42: 'grass',
#  43: 'grass',
#  44: 'grass',
#  45: 'bug',
#  46: 'bug',
#  47: 'bug',
#  48: 'bug',
#  49: 'ground',
#  50: 'ground',
#  51: 'normal',
#  52: 'normal',
#  53: 'water',
#  54: 'water',
#  55: 'fighting',
#  56: 'fighting',
#  57: 'fire',
#  58: 'fire',
#  59: 'water',
#  60: 'water',
#  61: 'water',
# ...

# %%
max(pokemon)
# Out:
# 'water'

# %%
min(pokemon)
# Out:
# 'bug'
